# %%
# !pip install pyforest

# %%
import pyforest

# %%
data=pd.read_csv('Desktop/titanic_ds.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data.shape
# Out:
# (418, 12)

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
from sklearn import preprocessing
label_en=preprocessing.LabelEncoder()
data['Sex']=label_en.fit_transform(data['Sex'])
data['Sex'].value_counts()
# Out:
# 1    266
# 0    152
# Name: Sex, dtype: int64

# %%
data['Sex'].isna().sum()
# Out:
# 0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
data=data.drop(['Name','Cabin','Ticket'],axis=1)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0            892         0       3    1  34.5      0      0    7.8292        Q
# 1            893         1       3    0  47.0      1      0    7.0000        S
# 2            894         0       2    1  62.0      0      0    9.6875        Q
# 3            895         0       3    1  27.0      0      0    8.6625        S
# 4            896         1       3    0  22.0      1      1   12.2875        S
# ..           ...       ...     ...  ...   ...    ...    ...       ...      ...
# 413         1305         0       3    1   NaN      0      0    8.0500        S
# 414         1306         1       1    0  39.0      0      0  108.9000        C
# 415         1307         0       3    1  38.5      0      0    7.2500        S
# 416         1308         0       3    1   NaN      0      0    8.0500        S
# 417         1309         0       3    1   NaN      1      1   22.3583        C
#
# [418 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Sex             0
# Age            86
# SibSp           0
# Parch           0
# Fare            1
# Embarked        0
# dtype: int64

# %%
data['Age'].median()
# Out:
# 27.0

# %%
data['Age']=data['Age'].fillna(value=27)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare Embarked
# 0            892         0       3    1  34.5      0      0    7.8292        Q
# 1            893         1       3    0  47.0      1      0    7.0000        S
# 2            894         0       2    1  62.0      0      0    9.6875        Q
# 3            895         0       3    1  27.0      0      0    8.6625        S
# 4            896         1       3    0  22.0      1      1   12.2875        S
# ..           ...       ...     ...  ...   ...    ...    ...       ...      ...
# 413         1305         0       3    1  27.0      0      0    8.0500        S
# 414         1306         1       1    0  39.0      0      0  108.9000        C
# 415         1307         0       3    1  38.5      0      0    7.2500        S
# 416         1308         0       3    1  27.0      0      0    8.0500        S
# 417         1309         0       3    1  27.0      1      1   22.3583        C
#
# [418 rows x 9 columns]

# %%
data['Age'].isna().sum()
# Out:
# 0

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# dtype: int64

# %%
data['Fare'].mode()
# Out:
# 0    7.75
# Name: Fare, dtype: float64

# %%
data['Fare']=data['Fare'].fillna(value=7.75)

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data['Embarked']
# Out:
# 0      Q
# 1      S
# 2      Q
# 3      S
# 4      S
#       ..
# 413    S
# 414    C
# 415    S
# 416    S
# 417    C
# Name: Embarked, Length: 418, dtype: object

# %%
from sklearn import preprocessing
label_en=preprocessing.LabelEncoder()
data['Embarked']=label_en.fit_transform(data['Embarked'])
data['Embarked'].value_counts()
# Out:
# 2    270
# 0    102
# 1     46
# Name: Embarked, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0            892         0       3    1  34.5      0      0    7.8292
# 1            893         1       3    0  47.0      1      0    7.0000
# 2            894         0       2    1  62.0      0      0    9.6875
# 3            895         0       3    1  27.0      0      0    8.6625
# 4            896         1       3    0  22.0      1      1   12.2875
# ..           ...       ...     ...  ...   ...    ...    ...       ...
# 413         1305         0       3    1  27.0      0      0    8.0500
# 414         1306         1       1    0  39.0      0      0  108.9000
# 415         1307         0       3    1  38.5      0      0    7.2500
# 416         1308         0       3    1  27.0      0      0    8.0500
# 417         1309         0       3    1  27.0      1      1   22.3583
#
#      Embarked
# 0           1
# 1           2
# 2           1
# 3           2
# 4           2
# ..        ...
# 413         2
# ...

# %%
sns.countplot(data['Embarked'],hue=data['Survived'])
plt.show
# Out:
# C:\Users\soppoju narender\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.023245 -0.026751  0.023245 -0.031447  0.003818
# Survived       -0.023245  1.000000 -0.108615 -1.000000  0.008035  0.099943
# Pclass         -0.026751 -0.108615  1.000000  0.108615 -0.467853  0.001087
# Sex             0.023245 -1.000000  0.108615  1.000000 -0.008035 -0.099943
# Age            -0.031447  0.008035 -0.467853 -0.008035  1.000000 -0.071197
# SibSp           0.003818  0.099943  0.001087 -0.099943 -0.071197  1.000000
# Parch           0.043080  0.159120  0.018721 -0.159120 -0.043731  0.306895
# Fare            0.008767  0.192229 -0.577491 -0.192229  0.341614  0.172034
# Embarked        0.040699 -0.076281  0.227983  0.076281 -0.148051  0.052708
#
#                 Parch      Fare  Embarked
# PassengerId  0.043080  0.008767  0.040699
# Survived     0.159120  0.192229 -0.076281
# Pclass       0.018721 -0.577491  0.227983
# Sex         -0.159120 -0.192229  0.076281
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
data['sibparch']=data['SibSp']+data['Parch']+1

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch      Fare  \
# 0            892         0       3    1  34.5      0      0    7.8292
# 1            893         1       3    0  47.0      1      0    7.0000
# 2            894         0       2    1  62.0      0      0    9.6875
# 3            895         0       3    1  27.0      0      0    8.6625
# 4            896         1       3    0  22.0      1      1   12.2875
# ..           ...       ...     ...  ...   ...    ...    ...       ...
# 413         1305         0       3    1  27.0      0      0    8.0500
# 414         1306         1       1    0  39.0      0      0  108.9000
# 415         1307         0       3    1  38.5      0      0    7.2500
# 416         1308         0       3    1  27.0      0      0    8.0500
# 417         1309         0       3    1  27.0      1      1   22.3583
#
#      Embarked  sibparch
# 0           1         1
# 1           2         2
# 2           1         1
# 3           2         1
# ...

# %%
data=data.drop(['SibSp','Parch','PassengerId','Embarked'],axis=1)

# %%
data
# Out:
#      Survived  Pclass  Sex   Age      Fare  sibparch
# 0           0       3    1  34.5    7.8292         1
# 1           1       3    0  47.0    7.0000         2
# 2           0       2    1  62.0    9.6875         1
# 3           0       3    1  27.0    8.6625         1
# 4           1       3    0  22.0   12.2875         3
# ..        ...     ...  ...   ...       ...       ...
# 413         0       3    1  27.0    8.0500         1
# 414         1       1    0  39.0  108.9000         1
# 415         0       3    1  38.5    7.2500         1
# 416         0       3    1  27.0    8.0500         1
# 417         0       3    1  27.0   22.3583         3
#
# [418 rows x 6 columns]

# %%
x=data.drop('Survived',axis=1).values
y=data['Survived'].values

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lrpredict=lr.predict(x_test)

# %%
accuracy_score(y_test,lrpredict)
# Out:
# 1.0

# %%
from sklearn.model_selection import GridSearchCV
c_space=np.logspace(-5,8,15)
param_grid={'C':c_space}
logreg_cv=GridSearchCV(lr,param_grid,cv=5)
logreg_cv.fit(x_train,y_train)
print("tuned logistic regression parameters {}".format(logreg_cv.best_params_))
print("best score {}".format(logreg_cv.best_score_))
# Out:
# tuned logistic regression parameters {'C': 0.4393970560760795}
# best score 1.0
